# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to make a local copy of the MNIST 1D repository
# !git clone https://github.com/greydanus/mnist1d
# Out:
# fatal: destination path 'mnist1d' already exists and is not an empty directory.

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TO DO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
layer_list = []
input_size = D_i
output_size = D_k
for x in range(3):
  layer_list.append(nn.Linear(input_size, output_size))
  layer_list.append(nn.ReLU())
  input_size = output_size
layer_list.append(nn.Linear(input_size,D_o))
model = torch.nn.Sequential(*layer_list);

def weights_init(layer_in):
  # TO DO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  if isinstance(layer_in,nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)


# Call the function you just defined
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('long'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Epoch     0, train loss 1.658698, train error 66.25,  test loss 1.724122, test error 69.60
# Epoch     1, train loss 1.339128, train error 51.17,  test loss 1.446647, test error 57.60
# Epoch     2, train loss 1.162236, train error 43.75,  test loss 1.350648, test error 53.30
# Epoch     3, train loss 0.988851, train error 36.25,  test loss 1.246490, test error 49.10
# Epoch     4, train loss 0.854904, train error 30.90,  test loss 1.213244, test error 48.30
# Epoch     5, train loss 0.759871, train error 28.43,  test loss 1.158177, test error 43.70
# Epoch     6, train loss 0.630683, train error 21.75,  test loss 1.168966, test error 44.90
# Epoch     7, train loss 0.518429, train error 17.43,  test loss 1.128184, test error 41.80
# Epoch     8, train loss 0.483666, train error 17.03,  test loss 1.140585, test error 40.70
# Epoch     9, train loss 0.397370, train error 14.10,  test loss 1.189353, test error 40.10
# Epoch    10, train loss 0.251337, train error 6.60,  test loss 1.133054, test error 37.10
# Epoch    11, train loss 0.193244, train error 4.05,  test loss 1.130993, test error 36.00
# Epoch    12, train loss 0.168232, train error 3.65,  test loss 1.184185, test error 36.40
# Epoch    13, train loss 0.122326, train error 1.65,  test loss 1.225559, test error 36.20
# Epoch    14, train loss 0.104629, train error 1.45,  test loss 1.265305, test error 35.40
# Epoch    15, train loss 0.092758, train error 1.38,  test loss 1.335288, test error 37.10
# Epoch    16, train loss 0.071202, train error 0.53,  test loss 1.353712, test error 37.50
# Epoch    17, train loss 0.056116, train error 0.30,  test loss 1.392286, test error 35.80
# Epoch    18, train loss 0.044278, train error 0.03,  test loss 1.447176, test error 36.00
# Epoch    19, train loss 0.036683, train error 0.00,  test loss 1.468570, test error 35.60
# Epoch    20, train loss 0.029749, train error 0.00,  test loss 1.468972, test error 35.50
# Epoch    21, train loss 0.026687, train error 0.00,  test loss 1.490462, test error 34.90
# Epoch    22, train loss 0.025281, train error 0.00,  test loss 1.510541, test error 35.40
# Epoch    23, train loss 0.023717, train error 0.00,  test loss 1.540071, test error 35.00
# Epoch    24, train loss 0.021899, train error 0.00,  test loss 1.541930, test error 35.60
# Epoch    25, train loss 0.020228, train error 0.00,  test loss 1.558290, test error 35.50
# Epoch    26, train loss 0.019139, train error 0.00,  test loss 1.577041, test error 35.30
# Epoch    27, train loss 0.018073, train error 0.00,  test loss 1.585389, test error 35.00
# Epoch    28, train loss 0.017341, train error 0.00,  test loss 1.601951, test error 35.30
# Epoch    29, train loss 0.016133, train error 0.00,  test loss 1.613950, test error 34.70
# Epoch    30, train loss 0.015665, train error 0.00,  test loss 1.617581, test error 34.80
# Epoch    31, train loss 0.015281, train error 0.00,  test loss 1.623827, test error 34.50
# Epoch    32, train loss 0.014873, train error 0.00,  test loss 1.631431, test error 34.70
# Epoch    33, train loss 0.014547, train error 0.00,  test loss 1.636880, test error 34.50
# Epoch    34, train loss 0.014213, train error 0.00,  test loss 1.642595, test error 34.90
# Epoch    35, train loss 0.013884, train error 0.00,  test loss 1.646644, test error 34.60
# Epoch    36, train loss 0.013614, train error 0.00,  test loss 1.657415, test error 34.40
# Epoch    37, train loss 0.013314, train error 0.00,  test loss 1.654900, test error 34.50
# Epoch    38, train loss 0.013061, train error 0.00,  test loss 1.667354, test error 34.30
# Epoch    39, train loss 0.012789, train error 0.00,  test loss 1.670785, test error 34.40
# Epoch    40, train loss 0.012595, train error 0.00,  test loss 1.672497, test error 34.70
# Epoch    41, train loss 0.012470, train error 0.00,  test loss 1.675360, test error 34.50
# Epoch    42, train loss 0.012342, train error 0.00,  test loss 1.678544, test error 34.60
# Epoch    43, train loss 0.012218, train error 0.00,  test loss 1.680390, test error 34.50
# Epoch    44, train loss 0.012104, train error 0.00,  test loss 1.683931, test error 34.50
# Epoch    45, train loss 0.011981, train error 0.00,  test loss 1.685553, test error 34.40
# Epoch    46, train loss 0.011859, train error 0.00,  test loss 1.688178, test error 34.70
# Epoch    47, train loss 0.011749, train error 0.00,  test loss 1.690031, test error 34.60
# Epoch    48, train loss 0.011631, train error 0.00,  test loss 1.692502, test error 34.40
# Epoch    49, train loss 0.011527, train error 0.00,  test loss 1.696121, test error 34.60

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TO DO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?

# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to make a local copy of the MNIST 1D repository
# !git clone https://github.com/greydanus/mnist1d
# Out:
# fatal: destination path 'mnist1d' already exists and is not an empty directory.

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cpu

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Length of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers of size 100
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  # create 100 dummy data points and store in data loader class
  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  # loop over the dataset n_epoch times
  n_epoch = 1000

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;
errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Train the model
    errors_train, errors_test = fit_model(model, data)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.302386, train error 89.57,  test loss 2.302755, test error 90.30
# Epoch   100, train loss 2.302213, train error 89.57,  test loss 2.303544, test error 90.30
# Epoch   200, train loss 2.302212, train error 89.57,  test loss 2.303484, test error 90.30
# Epoch   300, train loss 2.302221, train error 89.57,  test loss 2.303380, test error 90.30
# Epoch   400, train loss 2.302208, train error 89.57,  test loss 2.303426, test error 90.30
# Epoch   500, train loss 2.302210, train error 89.57,  test loss 2.303463, test error 90.30
# Epoch   600, train loss 2.302208, train error 89.57,  test loss 2.303447, test error 90.30
# Epoch   700, train loss 2.302210, train error 89.57,  test loss 2.303508, test error 90.30
# Epoch   800, train loss 2.302212, train error 89.57,  test loss 2.303377, test error 90.30
# Epoch   900, train loss 2.302211, train error 89.57,  test loss 2.303507, test error 90.30
# Training model with   4 hidden variables
# Epoch     0, train loss 2.297172, train error 88.50,  test loss 2.302430, test error 89.65
# Epoch   100, train loss 1.795765, train error 65.47,  test loss 1.620909, test error 63.38
# Epoch   200, train loss 1.787816, train error 66.03,  test loss 1.619558, test error 63.88
# Epoch   300, train loss 1.791635, train error 65.68,  test loss 1.643052, test error 63.22
# Epoch   400, train loss 1.785589, train error 65.78,  test loss 1.623185, test error 64.35
# Epoch   500, train loss 1.787663, train error 66.18,  test loss 1.623152, test error 64.20
# Epoch   600, train loss 1.781769, train error 65.82,  test loss 1.624359, test error 64.07
# Epoch   700, train loss 1.783365, train error 65.68,  test loss 1.637996, test error 64.12
# Epoch   800, train loss 1.783796, train error 65.53,  test loss 1.625470, test error 64.65
# Epoch   900, train loss 1.784701, train error 65.85,  test loss 1.639117, test error 63.78
# Training model with   6 hidden variables
# Epoch     0, train loss 2.245479, train error 83.97,  test loss 2.232867, test error 84.93
# Epoch   100, train loss 1.696546, train error 59.45,  test loss 1.539850, test error 56.65
# Epoch   200, train loss 1.622114, train error 55.85,  test loss 1.446267, test error 54.78
# Epoch   300, train loss 1.582836, train error 54.72,  test loss 1.396507, test error 52.22
# Epoch   400, train loss 1.577451, train error 53.92,  test loss 1.404456, test error 52.33
# Epoch   500, train loss 1.568836, train error 53.72,  test loss 1.396432, test error 52.05
# Epoch   600, train loss 1.559952, train error 53.33,  test loss 1.395390, test error 51.58
# Epoch   700, train loss 1.560698, train error 52.72,  test loss 1.395842, test error 51.75
# Epoch   800, train loss 1.559766, train error 53.17,  test loss 1.395972, test error 51.92
# Epoch   900, train loss 1.556876, train error 53.62,  test loss 1.397828, test error 51.70
# Training model with   8 hidden variables
# Epoch     0, train loss 2.184461, train error 79.70,  test loss 2.164541, test error 78.30
# Epoch   100, train loss 1.641430, train error 56.40,  test loss 1.445781, test error 55.78
# Epoch   200, train loss 1.592716, train error 55.83,  test loss 1.420510, test error 55.05
# Epoch   300, train loss 1.578199, train error 55.92,  test loss 1.417154, test error 54.78
# Epoch   400, train loss 1.572554, train error 55.22,  test loss 1.417270, test error 55.15
# Epoch   500, train loss 1.567425, train error 54.83,  test loss 1.408109, test error 55.03
# Epoch   600, train loss 1.558053, train error 55.05,  test loss 1.411513, test error 55.47
# Epoch   700, train loss 1.561094, train error 55.60,  test loss 1.415448, test error 55.60
# Epoch   800, train loss 1.552072, train error 54.88,  test loss 1.420546, test error 55.08
# Epoch   900, train loss 1.553295, train error 54.47,  test loss 1.426874, test error 55.20
# Training model with  10 hidden variables
# Epoch     0, train loss 2.303586, train error 89.45,  test loss 2.301161, test error 87.65
# Epoch   100, train loss 1.498430, train error 49.70,  test loss 1.304429, test error 48.80
# Epoch   200, train loss 1.468047, train error 48.30,  test loss 1.316524, test error 48.05
# Epoch   300, train loss 1.440069, train error 47.15,  test loss 1.302660, test error 47.60
# Epoch   400, train loss 1.425468, train error 47.28,  test loss 1.309243, test error 48.12
# Epoch   500, train loss 1.413146, train error 46.50,  test loss 1.331179, test error 47.58
# Epoch   600, train loss 1.404929, train error 46.78,  test loss 1.330362, test error 48.90
# Epoch   700, train loss 1.400141, train error 46.53,  test loss 1.339891, test error 48.40
# Epoch   800, train loss 1.400630, train error 46.12,  test loss 1.335920, test error 48.10
# Epoch   900, train loss 1.395428, train error 46.72,  test loss 1.347254, test error 48.42
# Training model with  14 hidden variables
# Epoch     0, train loss 2.203042, train error 81.97,  test loss 2.182095, test error 81.25
# Epoch   100, train loss 1.403963, train error 46.67,  test loss 1.282906, test error 47.20
# Epoch   200, train loss 1.357033, train error 45.90,  test loss 1.274603, test error 46.80
# Epoch   300, train loss 1.329514, train error 44.40,  test loss 1.290711, test error 45.78
# Epoch   400, train loss 1.319854, train error 45.25,  test loss 1.312302, test error 45.88
# Epoch   500, train loss 1.309942, train error 44.62,  test loss 1.330141, test error 47.80
# Epoch   600, train loss 1.293050, train error 44.33,  test loss 1.338357, test error 47.42
# Epoch   700, train loss 1.289672, train error 43.83,  test loss 1.347670, test error 47.50
# Epoch   800, train loss 1.296206, train error 44.38,  test loss 1.370889, test error 48.80
# Epoch   900, train loss 1.280478, train error 43.90,  test loss 1.360514, test error 48.17
# Training model with  18 hidden variables
# Epoch     0, train loss 2.166375, train error 82.68,  test loss 2.129656, test error 80.95
# Epoch   100, train loss 1.384296, train error 47.38,  test loss 1.394980, test error 51.60
# Epoch   200, train loss 1.309820, train error 45.20,  test loss 1.412846, test error 52.45
# Epoch   300, train loss 1.262357, train error 43.58,  test loss 1.460547, test error 52.65
# Epoch   400, train loss 1.245169, train error 43.12,  test loss 1.492318, test error 52.83
# Epoch   500, train loss 1.224916, train error 42.97,  test loss 1.515049, test error 51.72
# Epoch   600, train loss 1.216759, train error 42.03,  test loss 1.524052, test error 51.70
# Epoch   700, train loss 1.202116, train error 40.95,  test loss 1.570421, test error 52.40
# Epoch   800, train loss 1.189289, train error 41.50,  test loss 1.579761, test error 53.20
# Epoch   900, train loss 1.178416, train error 40.12,  test loss 1.626061, test error 53.72
# Training model with  22 hidden variables
# Epoch     0, train loss 2.250899, train error 81.50,  test loss 2.241734, test error 82.18
# Epoch   100, train loss 1.264966, train error 42.42,  test loss 1.319910, test error 48.62
# Epoch   200, train loss 1.158808, train error 39.28,  test loss 1.396155, test error 49.67
# Epoch   300, train loss 1.110057, train error 38.17,  test loss 1.451972, test error 50.90
# Epoch   400, train loss 1.077246, train error 36.42,  test loss 1.499909, test error 51.58
# Epoch   500, train loss 1.063028, train error 35.80,  test loss 1.549096, test error 51.80
# Epoch   600, train loss 1.046975, train error 35.70,  test loss 1.584249, test error 51.72
# Epoch   700, train loss 1.039077, train error 35.00,  test loss 1.607645, test error 52.70
# Epoch   800, train loss 1.017057, train error 34.30,  test loss 1.615314, test error 51.70
# Epoch   900, train loss 1.014537, train error 34.47,  test loss 1.645972, test error 52.35
# Training model with  26 hidden variables
# Epoch     0, train loss 2.148671, train error 79.78,  test loss 2.099227, test error 78.47
# Epoch   100, train loss 1.219826, train error 39.90,  test loss 1.346626, test error 49.10
# Epoch   200, train loss 1.083011, train error 36.50,  test loss 1.455943, test error 50.47
# Epoch   300, train loss 0.990991, train error 33.45,  test loss 1.625298, test error 52.28
# Epoch   400, train loss 0.966368, train error 32.55,  test loss 1.712223, test error 52.83
# Epoch   500, train loss 0.918909, train error 31.75,  test loss 1.834360, test error 53.28
# Epoch   600, train loss 0.901974, train error 31.12,  test loss 1.974167, test error 54.20
# Epoch   700, train loss 0.874374, train error 29.68,  test loss 2.029591, test error 53.95
# Epoch   800, train loss 0.879632, train error 30.65,  test loss 2.145801, test error 54.67
# Epoch   900, train loss 0.829697, train error 28.78,  test loss 2.256437, test error 54.70
# Training model with  30 hidden variables
# Epoch     0, train loss 2.191626, train error 80.97,  test loss 2.175657, test error 81.55
# Epoch   100, train loss 1.134644, train error 36.88,  test loss 1.350672, test error 50.12
# Epoch   200, train loss 0.957905, train error 31.12,  test loss 1.533741, test error 51.05
# Epoch   300, train loss 0.864169, train error 28.50,  test loss 1.745560, test error 52.45
# Epoch   400, train loss 0.804433, train error 27.60,  test loss 1.995278, test error 53.50
# Epoch   500, train loss 0.776472, train error 26.30,  test loss 2.142103, test error 54.28
# Epoch   600, train loss 0.746295, train error 26.00,  test loss 2.338832, test error 54.55
# Epoch   700, train loss 0.697903, train error 23.20,  test loss 2.462340, test error 54.65
# Epoch   800, train loss 0.704021, train error 23.78,  test loss 2.653095, test error 55.72
# Epoch   900, train loss 0.706245, train error 25.07,  test loss 2.706469, test error 56.08
# Training model with  35 hidden variables
# Epoch     0, train loss 2.184013, train error 79.65,  test loss 2.150820, test error 79.50
# Epoch   100, train loss 1.013590, train error 33.00,  test loss 1.417182, test error 50.12
# Epoch   200, train loss 0.816211, train error 27.60,  test loss 1.695099, test error 52.35
# Epoch   300, train loss 0.693174, train error 22.53,  test loss 2.026134, test error 54.45
# Epoch   400, train loss 0.647301, train error 22.00,  test loss 2.346125, test error 54.45
# Epoch   500, train loss 0.586490, train error 19.88,  test loss 2.659375, test error 55.28
# Epoch   600, train loss 0.551457, train error 19.05,  test loss 3.036467, test error 57.00
# Epoch   700, train loss 0.545679, train error 19.88,  test loss 3.219377, test error 56.05
# Epoch   800, train loss 0.498842, train error 17.07,  test loss 3.501884, test error 56.50
# Epoch   900, train loss 0.484930, train error 16.90,  test loss 3.800810, test error 57.85
# Training model with  40 hidden variables
# Epoch     0, train loss 2.057402, train error 76.47,  test loss 1.987032, test error 76.07
# Epoch   100, train loss 0.931351, train error 29.97,  test loss 1.450837, test error 49.22
# Epoch   200, train loss 0.665994, train error 21.80,  test loss 1.953212, test error 52.85
# Epoch   300, train loss 0.492335, train error 15.93,  test loss 2.585671, test error 54.42
# Epoch   400, train loss 0.441224, train error 14.70,  test loss 3.320559, test error 55.22
# Epoch   500, train loss 0.381772, train error 13.32,  test loss 3.999877, test error 56.28
# Epoch   600, train loss 0.317667, train error 10.65,  test loss 4.679659, test error 56.65
# Epoch   700, train loss 0.277970, train error 9.47,  test loss 5.316089, test error 56.83
# Epoch   800, train loss 0.286976, train error 10.65,  test loss 5.991883, test error 57.30
# Epoch   900, train loss 0.356387, train error 12.50,  test loss 6.669286, test error 56.17
# Training model with  45 hidden variables
# Epoch     0, train loss 2.110620, train error 78.25,  test loss 2.048485, test error 76.88
# Epoch   100, train loss 0.866040, train error 27.72,  test loss 1.531882, test error 52.08
# Epoch   200, train loss 0.514435, train error 16.53,  test loss 2.326756, test error 55.17
# Epoch   300, train loss 0.331045, train error 10.05,  test loss 3.322228, test error 56.83
# Epoch   400, train loss 0.250333, train error 8.40,  test loss 4.518378, test error 57.67
# Epoch   500, train loss 0.168078, train error 5.72,  test loss 5.715742, test error 57.38
# Epoch   600, train loss 0.178847, train error 6.70,  test loss 6.891567, test error 57.22
# Epoch   700, train loss 0.017952, train error 0.03,  test loss 8.143034, test error 57.38
# Epoch   800, train loss 0.011201, train error 0.03,  test loss 8.958508, test error 57.33
# Epoch   900, train loss 0.008043, train error 0.00,  test loss 9.582682, test error 57.38
# Training model with  50 hidden variables
# Epoch     0, train loss 2.104784, train error 79.10,  test loss 2.037740, test error 77.70
# Epoch   100, train loss 0.726660, train error 22.85,  test loss 1.558869, test error 50.25
# Epoch   200, train loss 0.349621, train error 11.05,  test loss 2.639843, test error 53.03
# Epoch   300, train loss 0.173095, train error 4.65,  test loss 4.195499, test error 54.12
# Epoch   400, train loss 0.035170, train error 0.07,  test loss 5.719270, test error 55.00
# Epoch   500, train loss 0.013605, train error 0.00,  test loss 6.689090, test error 54.58
# Epoch   600, train loss 0.008566, train error 0.00,  test loss 7.333908, test error 54.97
# Epoch   700, train loss 0.006098, train error 0.00,  test loss 7.800400, test error 54.92
# Epoch   800, train loss 0.004730, train error 0.00,  test loss 8.177226, test error 54.95
# Epoch   900, train loss 0.003777, train error 0.00,  test loss 8.483370, test error 55.08
# Training model with  55 hidden variables
# Epoch     0, train loss 2.095921, train error 76.43,  test loss 2.062402, test error 75.95
# Epoch   100, train loss 0.632580, train error 19.28,  test loss 1.658198, test error 50.05
# Epoch   200, train loss 0.228992, train error 5.75,  test loss 3.162885, test error 55.15
# Epoch   300, train loss 0.046255, train error 0.07,  test loss 5.002436, test error 56.67
# Epoch   400, train loss 0.014714, train error 0.00,  test loss 6.176257, test error 56.53
# Epoch   500, train loss 0.008613, train error 0.00,  test loss 6.867185, test error 56.20
# Epoch   600, train loss 0.005837, train error 0.00,  test loss 7.370809, test error 56.45
# Epoch   700, train loss 0.004371, train error 0.00,  test loss 7.751566, test error 56.42
# Epoch   800, train loss 0.003446, train error 0.00,  test loss 8.062778, test error 56.40
# Epoch   900, train loss 0.002826, train error 0.00,  test loss 8.327203, test error 56.42
# Training model with  60 hidden variables
# Epoch     0, train loss 2.070965, train error 78.47,  test loss 2.005099, test error 77.93
# Epoch   100, train loss 0.525503, train error 15.03,  test loss 1.716083, test error 50.67
# Epoch   200, train loss 0.101874, train error 0.82,  test loss 3.388135, test error 53.50
# Epoch   300, train loss 0.019408, train error 0.00,  test loss 4.715607, test error 54.40
# Epoch   400, train loss 0.009203, train error 0.00,  test loss 5.407680, test error 54.67
# Epoch   500, train loss 0.005856, train error 0.00,  test loss 5.842366, test error 54.53
# Epoch   600, train loss 0.004182, train error 0.00,  test loss 6.170606, test error 54.75
# Epoch   700, train loss 0.003236, train error 0.00,  test loss 6.442627, test error 54.88
# Epoch   800, train loss 0.002598, train error 0.00,  test loss 6.657515, test error 54.72
# Epoch   900, train loss 0.002168, train error 0.00,  test loss 6.843612, test error 54.47
# Training model with  70 hidden variables
# Epoch     0, train loss 2.068396, train error 76.28,  test loss 2.010206, test error 75.90
# Epoch   100, train loss 0.394567, train error 10.10,  test loss 1.943657, test error 51.85
# Epoch   200, train loss 0.035236, train error 0.00,  test loss 3.742692, test error 53.55
# Epoch   300, train loss 0.011161, train error 0.00,  test loss 4.600406, test error 53.65
# Epoch   400, train loss 0.006196, train error 0.00,  test loss 5.081120, test error 53.67
# Epoch   500, train loss 0.004151, train error 0.00,  test loss 5.409756, test error 53.95
# Epoch   600, train loss 0.003067, train error 0.00,  test loss 5.654556, test error 54.00
# Epoch   700, train loss 0.002410, train error 0.00,  test loss 5.861673, test error 54.22
# Epoch   800, train loss 0.001972, train error 0.00,  test loss 6.030861, test error 54.17
# Epoch   900, train loss 0.001657, train error 0.00,  test loss 6.178467, test error 54.30
# Training model with  80 hidden variables
# Epoch     0, train loss 1.987963, train error 73.47,  test loss 1.879755, test error 73.35
# Epoch   100, train loss 0.227818, train error 4.30,  test loss 2.155038, test error 51.65
# Epoch   200, train loss 0.018810, train error 0.00,  test loss 3.507038, test error 51.75
# Epoch   300, train loss 0.007669, train error 0.00,  test loss 4.068302, test error 52.25
# Epoch   400, train loss 0.004581, train error 0.00,  test loss 4.398663, test error 52.05
# Epoch   500, train loss 0.003175, train error 0.00,  test loss 4.640139, test error 52.50
# Epoch   600, train loss 0.002394, train error 0.00,  test loss 4.819417, test error 52.22
# Epoch   700, train loss 0.001901, train error 0.00,  test loss 4.969203, test error 52.20
# Epoch   800, train loss 0.001568, train error 0.00,  test loss 5.094347, test error 52.33
# Epoch   900, train loss 0.001327, train error 0.00,  test loss 5.202926, test error 52.38
# Training model with  90 hidden variables
# Epoch     0, train loss 1.999953, train error 74.22,  test loss 1.916146, test error 73.90
# Epoch   100, train loss 0.127586, train error 0.70,  test loss 2.280147, test error 53.03
# Epoch   200, train loss 0.013839, train error 0.00,  test loss 3.368736, test error 53.20
# Epoch   300, train loss 0.006221, train error 0.00,  test loss 3.808501, test error 53.22
# Epoch   400, train loss 0.003826, train error 0.00,  test loss 4.078332, test error 53.42
# Epoch   500, train loss 0.002696, train error 0.00,  test loss 4.275809, test error 53.30
# Epoch   600, train loss 0.002058, train error 0.00,  test loss 4.430047, test error 53.38
# Epoch   700, train loss 0.001646, train error 0.00,  test loss 4.557107, test error 53.35
# Epoch   800, train loss 0.001365, train error 0.00,  test loss 4.663672, test error 53.35
# Epoch   900, train loss 0.001161, train error 0.00,  test loss 4.755615, test error 53.28
# Training model with 100 hidden variables
# Epoch     0, train loss 2.015132, train error 75.25,  test loss 1.971868, test error 76.47
# Epoch   100, train loss 0.090708, train error 0.12,  test loss 2.276279, test error 51.70
# Epoch   200, train loss 0.011869, train error 0.00,  test loss 3.173429, test error 52.10
# Epoch   300, train loss 0.005564, train error 0.00,  test loss 3.540829, test error 52.22
# Epoch   400, train loss 0.003460, train error 0.00,  test loss 3.778375, test error 52.25
# Epoch   500, train loss 0.002466, train error 0.00,  test loss 3.949877, test error 52.28
# Epoch   600, train loss 0.001891, train error 0.00,  test loss 4.083934, test error 52.28
# Epoch   700, train loss 0.001521, train error 0.00,  test loss 4.194001, test error 52.22
# Epoch   800, train loss 0.001264, train error 0.00,  test loss 4.289577, test error 52.33
# Epoch   900, train loss 0.001077, train error 0.00,  test loss 4.371435, test error 52.30
# Training model with 120 hidden variables
# Epoch     0, train loss 1.976264, train error 72.72,  test loss 1.915938, test error 74.35
# Epoch   100, train loss 0.052744, train error 0.00,  test loss 2.174130, test error 49.80
# Epoch   200, train loss 0.009664, train error 0.00,  test loss 2.769776, test error 49.38
# Epoch   300, train loss 0.004753, train error 0.00,  test loss 3.026781, test error 49.70
# Epoch   400, train loss 0.003043, train error 0.00,  test loss 3.196677, test error 49.70
# Epoch   500, train loss 0.002189, train error 0.00,  test loss 3.324685, test error 49.67
# Epoch   600, train loss 0.001692, train error 0.00,  test loss 3.425107, test error 49.67
# Epoch   700, train loss 0.001368, train error 0.00,  test loss 3.507927, test error 49.65
# Epoch   800, train loss 0.001141, train error 0.00,  test loss 3.579142, test error 49.67
# Epoch   900, train loss 0.000975, train error 0.00,  test loss 3.639625, test error 49.70
# Training model with 140 hidden variables
# Epoch     0, train loss 1.971203, train error 72.65,  test loss 1.890258, test error 72.95
# Epoch   100, train loss 0.036673, train error 0.00,  test loss 2.261981, test error 49.88
# Epoch   200, train loss 0.008049, train error 0.00,  test loss 2.756706, test error 49.92
# Epoch   300, train loss 0.004156, train error 0.00,  test loss 2.994056, test error 50.12
# Epoch   400, train loss 0.002701, train error 0.00,  test loss 3.151029, test error 50.03
# Epoch   500, train loss 0.001966, train error 0.00,  test loss 3.266339, test error 49.75
# Epoch   600, train loss 0.001530, train error 0.00,  test loss 3.359215, test error 49.90
# Epoch   700, train loss 0.001243, train error 0.00,  test loss 3.435527, test error 49.95
# Epoch   800, train loss 0.001041, train error 0.00,  test loss 3.500477, test error 49.90
# Epoch   900, train loss 0.000892, train error 0.00,  test loss 3.557601, test error 49.88
# Training model with 160 hidden variables
# Epoch     0, train loss 1.938286, train error 71.00,  test loss 1.856263, test error 72.60
# Epoch   100, train loss 0.027843, train error 0.00,  test loss 2.171422, test error 49.35
# Epoch   200, train loss 0.007053, train error 0.00,  test loss 2.597290, test error 49.58
# Epoch   300, train loss 0.003693, train error 0.00,  test loss 2.809470, test error 49.72
# Epoch   400, train loss 0.002429, train error 0.00,  test loss 2.947811, test error 49.45
# Epoch   500, train loss 0.001781, train error 0.00,  test loss 3.051514, test error 49.47
# Epoch   600, train loss 0.001392, train error 0.00,  test loss 3.134105, test error 49.55
# Epoch   700, train loss 0.001134, train error 0.00,  test loss 3.203019, test error 49.58
# Epoch   800, train loss 0.000952, train error 0.00,  test loss 3.261112, test error 49.47
# Epoch   900, train loss 0.000818, train error 0.00,  test loss 3.313550, test error 49.45
# Training model with 180 hidden variables
# Epoch     0, train loss 1.954391, train error 72.75,  test loss 1.858317, test error 72.38
# Epoch   100, train loss 0.024926, train error 0.00,  test loss 2.111167, test error 49.25
# Epoch   200, train loss 0.006655, train error 0.00,  test loss 2.497764, test error 49.33
# Epoch   300, train loss 0.003553, train error 0.00,  test loss 2.688530, test error 49.45
# Epoch   400, train loss 0.002347, train error 0.00,  test loss 2.813972, test error 49.35
# Epoch   500, train loss 0.001726, train error 0.00,  test loss 2.909730, test error 49.33
# Epoch   600, train loss 0.001351, train error 0.00,  test loss 2.985761, test error 49.28
# Epoch   700, train loss 0.001103, train error 0.00,  test loss 3.048951, test error 49.30
# Epoch   800, train loss 0.000927, train error 0.00,  test loss 3.103166, test error 49.40
# Epoch   900, train loss 0.000797, train error 0.00,  test loss 3.150742, test error 49.47
# Training model with 200 hidden variables
# Epoch     0, train loss 1.940366, train error 71.15,  test loss 1.862977, test error 71.68
# Epoch   100, train loss 0.021055, train error 0.00,  test loss 2.039537, test error 48.60
# Epoch   200, train loss 0.006084, train error 0.00,  test loss 2.363559, test error 48.67
# Epoch   300, train loss 0.003316, train error 0.00,  test loss 2.532030, test error 48.85
# Epoch   400, train loss 0.002215, train error 0.00,  test loss 2.642159, test error 48.70
# Epoch   500, train loss 0.001635, train error 0.00,  test loss 2.725873, test error 48.80
# Epoch   600, train loss 0.001285, train error 0.00,  test loss 2.793092, test error 48.75
# Epoch   700, train loss 0.001051, train error 0.00,  test loss 2.849697, test error 48.75
# Epoch   800, train loss 0.000885, train error 0.00,  test loss 2.897918, test error 48.75
# Epoch   900, train loss 0.000762, train error 0.00,  test loss 2.940806, test error 48.80
# Training model with 250 hidden variables
# Epoch     0, train loss 1.899845, train error 69.60,  test loss 1.832081, test error 71.12
# Epoch   100, train loss 0.016858, train error 0.00,  test loss 1.959803, test error 48.55
# Epoch   200, train loss 0.005294, train error 0.00,  test loss 2.224566, test error 48.42
# Epoch   300, train loss 0.002948, train error 0.00,  test loss 2.365608, test error 48.47
# Epoch   400, train loss 0.001990, train error 0.00,  test loss 2.458662, test error 48.33
# Epoch   500, train loss 0.001482, train error 0.00,  test loss 2.530626, test error 48.25
# Epoch   600, train loss 0.001171, train error 0.00,  test loss 2.589618, test error 48.40
# Epoch   700, train loss 0.000961, train error 0.00,  test loss 2.637333, test error 48.42
# Epoch   800, train loss 0.000812, train error 0.00,  test loss 2.679614, test error 48.45
# Epoch   900, train loss 0.000701, train error 0.00,  test loss 2.716780, test error 48.53
# Training model with 300 hidden variables
# Epoch     0, train loss 1.890233, train error 68.55,  test loss 1.818359, test error 72.07
# Epoch   100, train loss 0.014568, train error 0.00,  test loss 1.901050, test error 46.22
# Epoch   200, train loss 0.004853, train error 0.00,  test loss 2.131867, test error 46.08
# Epoch   300, train loss 0.002748, train error 0.00,  test loss 2.253782, test error 46.10
# Epoch   400, train loss 0.001871, train error 0.00,  test loss 2.336573, test error 46.15
# Epoch   500, train loss 0.001399, train error 0.00,  test loss 2.400775, test error 46.00
# Epoch   600, train loss 0.001108, train error 0.00,  test loss 2.452466, test error 46.00
# Epoch   700, train loss 0.000912, train error 0.00,  test loss 2.495331, test error 46.03
# Epoch   800, train loss 0.000772, train error 0.00,  test loss 2.532320, test error 46.00
# Epoch   900, train loss 0.000667, train error 0.00,  test loss 2.565325, test error 46.03
# Training model with 400 hidden variables
# Epoch     0, train loss 1.858735, train error 66.90,  test loss 1.787963, test error 68.40
# Epoch   100, train loss 0.011511, train error 0.00,  test loss 1.837683, test error 46.45
# Epoch   200, train loss 0.004121, train error 0.00,  test loss 2.022835, test error 46.15
# Epoch   300, train loss 0.002391, train error 0.00,  test loss 2.126102, test error 46.12
# Epoch   400, train loss 0.001649, train error 0.00,  test loss 2.198378, test error 46.08
# Epoch   500, train loss 0.001243, train error 0.00,  test loss 2.254203, test error 45.92
# Epoch   600, train loss 0.000990, train error 0.00,  test loss 2.299449, test error 46.00
# Epoch   700, train loss 0.000819, train error 0.00,  test loss 2.337392, test error 45.90
# Epoch   800, train loss 0.000695, train error 0.00,  test loss 2.369997, test error 45.80
# Epoch   900, train loss 0.000602, train error 0.00,  test loss 2.398754, test error 45.67

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all,'r-',label='train')
ax.plot(hidden_variables, errors_test_all,'b-',label='test')
ax.set_ylim(0,100);
ax.set_xlabel('No hidden variables'); ax.set_ylabel('Error')
ax.legend()
plt.show()
